# %%
import requests #mandar un requerimiento a la API
import json #poder estructurar nuestros datos
import pandas as pd #para poder visualizar los datos en una estructura tabular

import warnings
warnings.filterwarnings("ignore")

# %%
SprintResults = {'raceName':[],
              'driverId':[],
              'constructorId':[],
              'number':[],
              'grid':[],
              'position':[],
              'positionText':[],
              'points':[],
              'laps':[],
              'time':[],
              'millis':[],
              'status':[],
              'fastestlap':[],
              'fastestlaptime':[]
          }

for year in list(range(2021,2023)):
    url = 'http://ergast.com/api/f1/{}/results.json'
    response = requests.get(url.format(year))
    content = json.loads(response.content)

    for i in range(0, len(content['MRData']['RaceTable']['Races'])):
        for item in content['MRData']['RaceTable']['Races'][i]['SprintResults']:
            SprintResults['raceName'].append(content['MRData']['RaceTable']['Races'][i]['raceName'])
            SprintResults['driverId'].append(item['Driver']['driverId'])
            SprintResults['constructorId'].append(item['Constructor']['constructorId'])
            SprintResults['number'].append(int(item['number']))
            SprintResults['grid'].append(int(item['grid']))
            SprintResults['position'].append(int(item['position']))
            SprintResults['positionText'].append(item['positionText'])
            SprintResults['points'].append(int(item['points']))
            SprintResults['laps'].append(int(item['laps']))
            SprintResults['status'].append(item['status'])
            try:
                SprintResults['time'].append(item['Time']['time'])
            except:
                SprintResults['time'].append(None)
            try:
                SprintResults['millis'].append(int(item['Time']['millis']))
            except:
                SprintResults['millis'].append(None)
            try:
                SprintResults['fastestlap'].append(item['FastestLap']['lap'])
            except:
                SprintResults['fastestlap'].append(None)
            try:
                SprintResults['fastestlaptime'].append(item['FastestLap']['Time']['time'])
            except:
                SprintResults['fastestlaptime'].append(None)
                          


pd.DataFrame(SprintResults)
# Out:
#                      raceName         driverId constructorId  number  grid  \
# 0          British Grand Prix   max_verstappen      red_bull      33     2
# 1          British Grand Prix         hamilton      mercedes      44     1
# 2          British Grand Prix           bottas      mercedes      77     3
# 3          British Grand Prix          leclerc       ferrari      16     4
# 4          British Grand Prix           norris       mclaren       4     6
# 5          British Grand Prix        ricciardo       mclaren       3     7
# 6          British Grand Prix           alonso        alpine      14    11
# 7          British Grand Prix           vettel  aston_martin       5    10
# 8          British Grand Prix          russell      williams      63     8
# 9          British Grand Prix             ocon        alpine      31    13
# 10         British Grand Prix            sainz       ferrari      55     9
# 11         British Grand Prix            gasly    alphatauri      10    12
# 12         British Grand Prix        raikkonen          alfa       7    17
# 13         British Grand Prix           stroll  aston_martin      18    15
# 14         British Grand Prix       giovinazzi          alfa      99    14
# 15         British Grand Prix          tsunoda    alphatauri      22    16
# 16         British Grand Prix           latifi      williams       6    18
# 17         British Grand Prix  mick_schumacher          haas      47    19
# 18         British Grand Prix          mazepin          haas       9    20
# 19         British Grand Prix            perez      red_bull      11     5
# 20         Italian Grand Prix           bottas      mercedes      77     1
# 21         Italian Grand Prix   max_verstappen      red_bull      33     3
# 22         Italian Grand Prix        ricciardo       mclaren       3     5
# 23         Italian Grand Prix           norris       mclaren       4     4
# 24         Italian Grand Prix         hamilton      mercedes      44     2
# 25         Italian Grand Prix          leclerc       ferrari      16     8
# 26         Italian Grand Prix            sainz       ferrari      55     7
# 27         Italian Grand Prix       giovinazzi          alfa      99    10
# 28         Italian Grand Prix            perez      red_bull      11     9
# 29         Italian Grand Prix           stroll  aston_martin      18    12
# 30  Emilia Romagna Grand Prix   max_verstappen      red_bull       1     1
# 31  Emilia Romagna Grand Prix          leclerc       ferrari      16     2
# 32  Emilia Romagna Grand Prix            perez      red_bull      11     7
# 33  Emilia Romagna Grand Prix            sainz       ferrari      55    10
# 34  Emilia Romagna Grand Prix           norris       mclaren       4     3
# 35  Emilia Romagna Grand Prix        ricciardo       mclaren       3     6
# 36  Emilia Romagna Grand Prix           bottas          alfa      77     8
# 37  Emilia Romagna Grand Prix  kevin_magnussen          haas      20     4
# 38  Emilia Romagna Grand Prix           alonso        alpine      14     5
# 39  Emilia Romagna Grand Prix  mick_schumacher          haas      47    12
# 40  Emilia Romagna Grand Prix          russell      mercedes      63    11
# 41  Emilia Romagna Grand Prix          tsunoda    alphatauri      22    16
# 42  Emilia Romagna Grand Prix           vettel  aston_martin       5     9
# 43  Emilia Romagna Grand Prix         hamilton      mercedes      44    13
# 44  Emilia Romagna Grand Prix           stroll  aston_martin      18    15
# 45  Emilia Romagna Grand Prix             ocon        alpine      31    19
# 46  Emilia Romagna Grand Prix            gasly    alphatauri      10    17
# 47  Emilia Romagna Grand Prix            albon      williams      23    20
# 48  Emilia Romagna Grand Prix           latifi      williams       6    18
# 49  Emilia Romagna Grand Prix             zhou          alfa      24     0
# 50        Austrian Grand Prix   max_verstappen      red_bull       1     1
# 51        Austrian Grand Prix          leclerc       ferrari      16     2
# 52        Austrian Grand Prix            sainz       ferrari      55     3
# 53        Austrian Grand Prix          russell      mercedes      63     4
# 54        Austrian Grand Prix            perez      red_bull      11    13
# 55        Austrian Grand Prix             ocon        alpine      31     5
# 56        Austrian Grand Prix  kevin_magnussen          haas      20     6
# 57        Austrian Grand Prix         hamilton      mercedes      44     9
# 58        Austrian Grand Prix  mick_schumacher          haas      47     7
# 59        Austrian Grand Prix           bottas          alfa      77    12
#
#     position positionText  points  laps       time     millis      status  \
# 0          1            1       3    17  25:38.426  1538426.0    Finished
# 1          2            2       2    17     +1.430  1539856.0    Finished
# 2          3            3       1    17     +7.502  1545928.0    Finished
# 3          4            4       0    17    +11.278  1549704.0    Finished
# 4          5            5       0    17    +24.111  1562537.0    Finished
# 5          6            6       0    17    +30.959  1569385.0    Finished
# 6          7            7       0    17    +43.527  1581953.0    Finished
# 7          8            8       0    17    +44.439  1582865.0    Finished
# 8          9            9       0    17    +46.652  1585078.0    Finished
# 9         10           10       0    17    +47.395  1585821.0    Finished
# 10        11           11       0    17    +47.798  1586224.0    Finished
# 11        12           12       0    17    +48.763  1587189.0    Finished
# 12        13           13       0    17    +50.677  1589103.0    Finished
# 13        14           14       0    17    +52.179  1590605.0    Finished
# 14        15           15       0    17    +53.225  1591651.0    Finished
# 15        16           16       0    17    +53.567  1591993.0    Finished
# 16        17           17       0    17    +55.162  1593588.0    Finished
# 17        18           18       0    17  +1:08.213  1606639.0    Finished
# 18        19           19       0    17  +1:17.648  1616074.0    Finished
# 19        20            R       0    16       None        NaN  Vibrations
# 20         1            1       3    18  27:54.078  1674078.0    Finished
# 21         2            2       2    18     +2.325  1676403.0    Finished
# 22         3            3       1    18    +14.534  1688612.0    Finished
# 23         4            4       0    18    +18.835  1692913.0    Finished
# 24         5            5       0    18    +20.011  1694089.0    Finished
# 25         6            6       0    18    +23.442  1697520.0    Finished
# 26         7            7       0    18    +27.952  1702030.0    Finished
# 27         8            8       0    18    +31.089  1705167.0    Finished
# 28         9            9       0    18    +31.680  1705758.0    Finished
# 29        10           10       0    18    +38.671  1712749.0    Finished
# 30         1            1       8    21  30:39.567  1839567.0    Finished
# 31         2            2       7    21     +2.975  1842542.0    Finished
# 32         3            3       6    21     +4.721  1844288.0    Finished
# 33         4            4       5    21    +17.578  1857145.0    Finished
# 34         5            5       4    21    +24.561  1864128.0    Finished
# 35         6            6       3    21    +27.740  1867307.0    Finished
# 36         7            7       2    21    +28.133  1867700.0    Finished
# 37         8            8       1    21    +30.712  1870279.0    Finished
# 38         9            9       0    21    +32.278  1871845.0    Finished
# 39        10           10       0    21    +33.773  1873340.0    Finished
# 40        11           11       0    21    +36.284  1875851.0    Finished
# 41        12           12       0    21    +38.298  1877865.0    Finished
# 42        13           13       0    21    +40.177  1879744.0    Finished
# 43        14           14       0    21    +41.459  1881026.0    Finished
# 44        15           15       0    21    +42.910  1882477.0    Finished
# 45        16           16       0    21    +43.517  1883084.0    Finished
# 46        17           17       0    21    +43.794  1883361.0    Finished
# 47        18           18       0    21    +48.871  1888438.0    Finished
# 48        19           19       0    21    +52.017  1891584.0    Finished
# 49        20            R       0     0       None        NaN     Retired
# 50         1            1       8    23  26:30.059  1590059.0    Finished
# 51         2            2       7    23     +1.675  1591734.0    Finished
# 52         3            3       6    23     +5.644  1595703.0    Finished
# 53         4            4       5    23    +13.429  1603488.0    Finished
# 54         5            5       4    23    +18.302  1608361.0    Finished
# 55         6            6       3    23    +31.032  1621091.0    Finished
# 56         7            7       2    23    +34.539  1624598.0    Finished
# 57         8            8       1    23    +35.447  1625506.0    Finished
# 58         9            9       0    23    +37.163  1627222.0    Finished
# 59        10           10       0    23    +37.557  1627616.0    Finished
#
#    fastestlap fastestlaptime
# 0          14       1:30.013
# 1          17       1:29.937
# 2          17       1:29.958
# 3          16       1:30.163
# 4          16       1:30.566
# 5          17       1:30.640
# 6          17       1:31.773
# 7          17       1:31.687
# 8          17       1:32.208
# 9          16       1:32.183
# 10         10       1:31.991
# 11         17       1:32.072
# 12         12       1:32.139
# 13         12       1:32.210
# 14         14       1:32.457
# 15         14       1:32.270
# 16         17       1:32.143
# 17         15       1:32.567
# 18          3       1:33.462
# 19          6       1:31.465
# 20          9       1:23.540
# 21          9       1:23.502
# 22         17       1:24.291
# 23          9       1:24.554
# 24          9       1:24.253
# 25         18       1:24.677
# 26          8       1:24.918
# 27         10       1:25.126
# 28         12       1:24.211
# 29          8       1:25.349
# 30         14       1:19.154
# 31         11       1:19.044
# 32         14       1:19.012
# 33         14       1:19.251
# 34          9       1:20.030
# 35         12       1:20.328
# 36          9       1:20.219
# 37          6       1:20.557
# 38         10       1:20.639
# 39         15       1:20.567
# 40         19       1:20.756
# 41         20       1:20.909
# 42          8       1:21.044
# 43          9       1:20.663
# 44         14       1:20.948
# 45         14       1:20.995
# 46         18       1:20.599
# 47         14       1:21.020
# 48         16       1:21.437
# 49       None           None
# 50          5       1:08.455
# 51          4       1:08.321
# 52          4       1:08.409
# 53          4       1:08.979
# 54         14       1:09.137
# 55          4       1:09.384
# 56          4       1:09.232
# 57          7       1:09.516
# 58          4       1:09.457
# 59          4       1:09.674

# %%
pd.DataFrame(SprintResults).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   raceName        60 non-null     object
#  1   driverId        60 non-null     object
#  2   constructorId   60 non-null     object
#  3   number          60 non-null     int64
#  4   grid            60 non-null     int64
#  5   position        60 non-null     int64
#  6   positionText    60 non-null     object
#  7   points          60 non-null     int64
#  8   laps            60 non-null     int64
#  9   time            58 non-null     object
#  10  millis          58 non-null     float64
#  11  status          60 non-null     object
#  12  fastestlap      59 non-null     object
#  13  fastestlaptime  59 non-null     object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 6.7+ KB

# %%
url='http://ergast.com/api/f1/2021/sprint.json'
response = requests.get(url)
content = json.loads(response.content)
content['MRData']['RaceTable']['Races'][0]
# Out:
# {'season': '2021',
#  'round': '10',
#  'url': 'http://en.wikipedia.org/wiki/2021_British_Grand_Prix',
#  'raceName': 'British Grand Prix',
#  'Circuit': {'circuitId': 'silverstone',
#   'url': 'http://en.wikipedia.org/wiki/Silverstone_Circuit',
#   'circuitName': 'Silverstone Circuit',
#   'Location': {'lat': '52.0786',
#    'long': '-1.01694',
#    'locality': 'Silverstone',
#    'country': 'UK'}},
#  'date': '2021-07-18',
#  'time': '14:00:00Z',
#  'SprintResults': [{'number': '33',
#    'position': '1',
#    'positionText': '1',
#    'points': '3',
#    'Driver': {'driverId': 'max_verstappen',
#     'permanentNumber': '33',
#     'code': 'VER',
#     'url': 'http://en.wikipedia.org/wiki/Max_Verstappen',
#     'givenName': 'Max',
#     'familyName': 'Verstappen',
#     'dateOfBirth': '1997-09-30',
#     'nationality': 'Dutch'},
#    'Constructor': {'constructorId': 'red_bull',
#     'url': 'http://en.wikipedia.org/wiki/Red_Bull_Racing',
#     'name': 'Red Bull',
#     'nationality': 'Austrian'},
#    'grid': '2',
#    'laps': '17',
#    'status': 'Finished',
#    'Time': {'millis': '1538426', 'time': '25:38.426'},
#    'FastestLap': {'lap': '14', 'Time': {'time': '1:30.013'}}},
#   {'number': '44',
#    'position': '2',
#    'positionText': '2',
#    'points': '2',
#    'Driver': {'driverId': 'hamilton',
#     'permanentNumber': '44',
#     'code': 'HAM',
#     'url': 'http://en.wikipedia.org/wiki/Lewis_Hamilton',
#     'givenName': 'Lewis',
#     'familyName': 'Hamilton',
#     'dateOfBirth': '1985-01-07',
#     'nationality': 'British'},
#    'Constructor': {'constructorId': 'mercedes',
#     'url': 'http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One',
#     'name': 'Mercedes',
#     'nationality': 'German'},
#    'grid': '1',
#    'laps': '17',
#    'status': 'Finished',
#    'Time': {'millis': '1539856', 'time': '+1.430'},
#    'FastestLap': {'lap': '17', 'Time': {'time': '1:29.937'}}},
#   {'number': '77',
#    'position': '3',
#    'positionText': '3',
#    'points': '1',
#    'Driver': {'driverId': 'bottas',
#     'permanentNumber': '77',
#     'code': 'BOT',
#     'url': 'http://en.wikipedia.org/wiki/Valtteri_Bottas',
#     'givenName': 'Valtteri',
#     'familyName': 'Bottas',
#     'dateOfBirth': '1989-08-28',
#     'nationality': 'Finnish'},
#    'Constructor': {'constructorId': 'mercedes',
#     'url': 'http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One',
#     'name': 'Mercedes',
#     'nationality': 'German'},
#    'grid': '3',
#    'laps': '17',
#    'status': 'Finished',
#    'Time': {'millis': '1545928', 'time': '+7.502'},
#    'FastestLap': {'lap': '17', 'Time': {'time': '1:29.958'}}},
#   {'number': '16',
#    'position': '4',
#    'positionText': '4',
#    'points': '0',
#    'Driver': {'driverId': 'leclerc',
#     'permanentNumber': '16',
#     'code': 'LEC',
#     'url': 'http://en.wikipedia.org/wiki/Charles_Leclerc',
#     'givenName': 'Charles',
#     'familyName': 'Leclerc',
#     'dateOfBirth': '1997-10-16',
#     'nationality': 'Monegasque'},
#    'Constructor': {'constructorId': 'ferrari',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#     'name': 'Ferrari',
#     'nationality': 'Italian'},
#    'grid': '4',
#    'laps': '17',
#    'status': 'Finished',
#    'Time': {'millis': '1549704', 'time': '+11.278'},
#    'FastestLap': {'lap': '16', 'Time': {'time': '1:30.163'}}},
#   {'number': '4',
#    'position': '5',
#    'positionText': '5',
#    'points': '0',
#    'Driver': {'driverId': 'norris',
#     'permanentNumber': '4',
#     'code': 'NOR',
#     'url': 'http://en.wikipedia.org/wiki/Lando_Norris',
#     'givenName': 'Lando',
#     'familyName': 'Norris',
#     'dateOfBirth': '1999-11-13',
#     'nationality': 'British'},
#    'Constructor': {'constructorId': 'mclaren',
#     'url': 'http://en.wikipedia.org/wiki/McLaren',
#     'name': 'McLaren',
#     'nationality': 'British'},
#    'grid': '6',
#    'laps': '17',
#    'status': 'Finished',
#    'Time': {'millis': '1562537', 'time': '+24.111'},
#    'FastestLap': {'lap': '16', 'Time': {'time': '1:30.566'}}},
#   {'number': '3',
#    'position': '6',
#    'positionText': '6',
#    'points': '0',
#    'Driver': {'driverId': 'ricciardo',
#     'permanentNumber': '3',
#     'code': 'RIC',
#     'url': 'http://en.wikipedia.org/wiki/Daniel_Ricciardo',
#     'givenName': 'Daniel',
#     'familyName': 'Ricciardo',
#     'dateOfBirth': '1989-07-01',
#     'nationality': 'Australian'},
#    'Constructor': {'constructorId': 'mclaren',
#     'url': 'http://en.wikipedia.org/wiki/McLaren',
#     'name': 'McLaren',
#     'nationality': 'British'},
#    'grid': '7',
#    'laps': '17',
#    'status': 'Finished',
#    'Time': {'millis': '1569385', 'time': '+30.959'},
#    'FastestLap': {'lap': '17', 'Time': {'time': '1:30.640'}}},
#   {'number': '14',
#    'position': '7',
#    'positionText': '7',
#    'points': '0',
#    'Driver': {'driverId': 'alonso',
#     'permanentNumber': '14',
#     'code': 'ALO',
#     'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#     'givenName': 'Fernando',
#     'familyName': 'Alonso',
#     'dateOfBirth': '1981-07-29',
#     'nationality': 'Spanish'},
#    'Constructor': {'constructorId': 'alpine',
#     'url': 'http://en.wikipedia.org/wiki/Alpine_F1_Team',
#     'name': 'Alpine F1 Team',
#     'nationality': 'French'},
#    'grid': '11',
#    'laps': '17',
#    'status': 'Finished',
#    'Time': {'millis': '1581953', 'time': '+43.527'},
#    'FastestLap': {'lap': '17', 'Time': {'time': '1:31.773'}}},
#   {'number': '5',
#    'position': '8',
#    'positionText': '8',
#    'points': '0',
#    'Driver': {'driverId': 'vettel',
#     'permanentNumber': '5',
#     'code': 'VET',
#     'url': 'http://en.wikipedia.org/wiki/Sebastian_Vettel',
#     'givenName': 'Sebastian',
#     'familyName': 'Vettel',
#     'dateOfBirth': '1987-07-03',
#     'nationality': 'German'},
#    'Constructor': {'constructorId': 'aston_martin',
#     'url': 'http://en.wikipedia.org/wiki/Aston_Martin_in_Formula_One',
#     'name': 'Aston Martin',
#     'nationality': 'British'},
#    'grid': '10',
#    'laps': '17',
#    'status': 'Finished',
#    'Time': {'millis': '1582865', 'time': '+44.439'},
#    'FastestLap': {'lap': '17', 'Time': {'time': '1:31.687'}}},
#   {'number': '63',
#    'position': '9',
#    'positionText': '9',
#    'points': '0',
#    'Driver': {'driverId': 'russell',
#     'permanentNumber': '63',
#     'code': 'RUS',
#     'url': 'http://en.wikipedia.org/wiki/George_Russell_%28racing_driver%29',
#     'givenName': 'George',
#     'familyName': 'Russell',
#     'dateOfBirth': '1998-02-15',
#     'nationality': 'British'},
#    'Constructor': {'constructorId': 'williams',
#     'url': 'http://en.wikipedia.org/wiki/Williams_Grand_Prix_Engineering',
#     'name': 'Williams',
#     'nationality': 'British'},
#    'grid': '8',
#    'laps': '17',
#    'status': 'Finished',
#    'Time': {'millis': '1585078', 'time': '+46.652'},
#    'FastestLap': {'lap': '17', 'Time': {'time': '1:32.208'}}},
#   {'number': '31',
#    'position': '10',
#    'positionText': '10',
#    'points': '0',
#    'Driver': {'driverId': 'ocon',
#     'permanentNumber': '31',
#     'code': 'OCO',
#     'url': 'http://en.wikipedia.org/wiki/Esteban_Ocon',
#     'givenName': 'Esteban',
#     'familyName': 'Ocon',
#     'dateOfBirth': '1996-09-17',
#     'nationality': 'French'},
#    'Constructor': {'constructorId': 'alpine',
#     'url': 'http://en.wikipedia.org/wiki/Alpine_F1_Team',
#     'name': 'Alpine F1 Team',
#     'nationality': 'French'},
#    'grid': '13',
#    'laps': '17',
#    'status': 'Finished',
#    'Time': {'millis': '1585821', 'time': '+47.395'},
#    'FastestLap': {'lap': '16', 'Time': {'time': '1:32.183'}}},
#   {'number': '55',
#    'position': '11',
#    'positionText': '11',
#    'points': '0',
#    'Driver': {'driverId': 'sainz',
#     'permanentNumber': '55',
#     'code': 'SAI',
#     'url': 'http://en.wikipedia.org/wiki/Carlos_Sainz_Jr.',
#     'givenName': 'Carlos',
#     'familyName': 'Sainz',
#     'dateOfBirth': '1994-09-01',
#     'nationality': 'Spanish'},
#    'Constructor': {'constructorId': 'ferrari',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#     'name': 'Ferrari',
#     'nationality': 'Italian'},
#    'grid': '9',
#    'laps': '17',
#    'status': 'Finished',
#    'Time': {'millis': '1586224', 'time': '+47.798'},
#    'FastestLap': {'lap': '10', 'Time': {'time': '1:31.991'}}},
#   {'number': '10',
#    'position': '12',
#    'positionText': '12',
#    'points': '0',
#    'Driver': {'driverId': 'gasly',
#     'permanentNumber': '10',
#     'code': 'GAS',
#     'url': 'http://en.wikipedia.org/wiki/Pierre_Gasly',
#     'givenName': 'Pierre',
#     'familyName': 'Gasly',
#     'dateOfBirth': '1996-02-07',
#     'nationality': 'French'},
#    'Constructor': {'constructorId': 'alphatauri',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_AlphaTauri',
#     'name': 'AlphaTauri',
#     'nationality': 'Italian'},
#    'grid': '12',
#    'laps': '17',
#    'status': 'Finished',
#    'Time': {'millis': '1587189', 'time': '+48.763'},
#    'FastestLap': {'lap': '17', 'Time': {'time': '1:32.072'}}},
#   {'number': '7',
#    'position': '13',
#    'positionText': '13',
#    'points': '0',
#    'Driver': {'driverId': 'raikkonen',
#     'permanentNumber': '7',
#     'code': 'RAI',
#     'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#     'givenName': 'Kimi',
#     'familyName': 'Räikkönen',
#     'dateOfBirth': '1979-10-17',
#     'nationality': 'Finnish'},
#    'Constructor': {'constructorId': 'alfa',
#     'url': 'http://en.wikipedia.org/wiki/Alfa_Romeo_in_Formula_One',
#     'name': 'Alfa Romeo',
#     'nationality': 'Swiss'},
#    'grid': '17',
#    'laps': '17',
#    'status': 'Finished',
#    'Time': {'millis': '1589103', 'time': '+50.677'},
#    'FastestLap': {'lap': '12', 'Time': {'time': '1:32.139'}}},
#   {'number': '18',
#    'position': '14',
#    'positionText': '14',
#    'points': '0',
#    'Driver': {'driverId': 'stroll',
#     'permanentNumber': '18',
#     'code': 'STR',
#     'url': 'http://en.wikipedia.org/wiki/Lance_Stroll',
#     'givenName': 'Lance',
#     'familyName': 'Stroll',
#     'dateOfBirth': '1998-10-29',
#     'nationality': 'Canadian'},
#    'Constructor': {'constructorId': 'aston_martin',
#     'url': 'http://en.wikipedia.org/wiki/Aston_Martin_in_Formula_One',
#     'name': 'Aston Martin',
#     'nationality': 'British'},
#    'grid': '15',
#    'laps': '17',
#    'status': 'Finished',
#    'Time': {'millis': '1590605', 'time': '+52.179'},
#    'FastestLap': {'lap': '12', 'Time': {'time': '1:32.210'}}},
#   {'number': '99',
#    'position': '15',
#    'positionText': '15',
#    'points': '0',
#    'Driver': {'driverId': 'giovinazzi',
#     'permanentNumber': '99',
#     'code': 'GIO',
#     'url': 'http://en.wikipedia.org/wiki/Antonio_Giovinazzi',
#     'givenName': 'Antonio',
#     'familyName': 'Giovinazzi',
#     'dateOfBirth': '1993-12-14',
#     'nationality': 'Italian'},
#    'Constructor': {'constructorId': 'alfa',
#     'url': 'http://en.wikipedia.org/wiki/Alfa_Romeo_in_Formula_One',
#     'name': 'Alfa Romeo',
#     'nationality': 'Swiss'},
#    'grid': '14',
#    'laps': '17',
#    'status': 'Finished',
#    'Time': {'millis': '1591651', 'time': '+53.225'},
#    'FastestLap': {'lap': '14', 'Time': {'time': '1:32.457'}}},
#   {'number': '22',
#    'position': '16',
#    'positionText': '16',
#    'points': '0',
#    'Driver': {'driverId': 'tsunoda',
#     'permanentNumber': '22',
#     'code': 'TSU',
#     'url': 'http://en.wikipedia.org/wiki/Yuki_Tsunoda',
#     'givenName': 'Yuki',
#     'familyName': 'Tsunoda',
#     'dateOfBirth': '2000-05-11',
#     'nationality': 'Japanese'},
#    'Constructor': {'constructorId': 'alphatauri',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_AlphaTauri',
#     'name': 'AlphaTauri',
#     'nationality': 'Italian'},
#    'grid': '16',
#    'laps': '17',
#    'status': 'Finished',
#    'Time': {'millis': '1591993', 'time': '+53.567'},
#    'FastestLap': {'lap': '14', 'Time': {'time': '1:32.270'}}},
#   {'number': '6',
#    'position': '17',
#    'positionText': '17',
#    'points': '0',
#    'Driver': {'driverId': 'latifi',
#     'permanentNumber': '6',
#     'code': 'LAT',
#     'url': 'http://en.wikipedia.org/wiki/Nicholas_Latifi',
#     'givenName': 'Nicholas',
#     'familyName': 'Latifi',
#     'dateOfBirth': '1995-06-29',
#     'nationality': 'Canadian'},
#    'Constructor': {'constructorId': 'williams',
#     'url': 'http://en.wikipedia.org/wiki/Williams_Grand_Prix_Engineering',
#     'name': 'Williams',
#     'nationality': 'British'},
#    'grid': '18',
#    'laps': '17',
#    'status': 'Finished',
#    'Time': {'millis': '1593588', 'time': '+55.162'},
#    'FastestLap': {'lap': '17', 'Time': {'time': '1:32.143'}}},
#   {'number': '47',
#    'position': '18',
#    'positionText': '18',
#    'points': '0',
#    'Driver': {'driverId': 'mick_schumacher',
#     'permanentNumber': '47',
#     'code': 'MSC',
#     'url': 'http://en.wikipedia.org/wiki/Mick_Schumacher',
#     'givenName': 'Mick',
#     'familyName': 'Schumacher',
#     'dateOfBirth': '1999-03-22',
#     'nationality': 'German'},
#    'Constructor': {'constructorId': 'haas',
#     'url': 'http://en.wikipedia.org/wiki/Haas_F1_Team',
#     'name': 'Haas F1 Team',
#     'nationality': 'American'},
#    'grid': '19',
#    'laps': '17',
#    'status': 'Finished',
#    'Time': {'millis': '1606639', 'time': '+1:08.213'},
#    'FastestLap': {'lap': '15', 'Time': {'time': '1:32.567'}}},
#   {'number': '9',
#    'position': '19',
#    'positionText': '19',
#    'points': '0',
#    'Driver': {'driverId': 'mazepin',
#     'permanentNumber': '9',
#     'code': 'MAZ',
#     'url': 'http://en.wikipedia.org/wiki/Nikita_Mazepin',
#     'givenName': 'Nikita',
#     'familyName': 'Mazepin',
#     'dateOfBirth': '1999-03-02',
#     'nationality': 'Russian'},
#    'Constructor': {'constructorId': 'haas',
#     'url': 'http://en.wikipedia.org/wiki/Haas_F1_Team',
#     'name': 'Haas F1 Team',
#     'nationality': 'American'},
#    'grid': '20',
#    'laps': '17',
#    'status': 'Finished',
#    'Time': {'millis': '1616074', 'time': '+1:17.648'},
#    'FastestLap': {'lap': '3', 'Time': {'time': '1:33.462'}}},
#   {'number': '11',
#    'position': '20',
#    'positionText': 'R',
#    'points': '0',
#    'Driver': {'driverId': 'perez',
#     'permanentNumber': '11',
#     'code': 'PER',
#     'url': 'http://en.wikipedia.org/wiki/Sergio_P%C3%A9rez',
#     'givenName': 'Sergio',
#     'familyName': 'Pérez',
#     'dateOfBirth': '1990-01-26',
#     'nationality': 'Mexican'},
#    'Constructor': {'constructorId': 'red_bull',
#     'url': 'http://en.wikipedia.org/wiki/Red_Bull_Racing',
#     'name': 'Red Bull',
#     'nationality': 'Austrian'},
#    'grid': '5',
#    'laps': '16',
#    'status': 'Vibrations',
#    'FastestLap': {'lap': '6', 'Time': {'time': '1:31.465'}}}]}

# %%
for i in range(0,19):
    print(content['MRData']['RaceTable']['Races'][0]['SprintResults'][i]['Time']['time'])
# Out:
# 30:39.567
# +2.975
# +4.721
# +17.578
# +24.561
# +27.740
# +28.133
# +30.712
# +32.278
# +33.773
# +36.284
# +38.298
# +40.177
# +41.459
# +42.910
# +43.517
# +43.794
# +48.871
# +52.017

# %%
content['MRData']['RaceTable']['Races'][0].keys()
# Out:
# dict_keys(['season', 'round', 'url', 'raceName', 'Circuit', 'date', 'time', 'SprintResults'])

# %%
len(content['MRData']['RaceTable']['Races'])
# Out:
# 2

# %%
SprintResults = {'raceName':[],
              #'driverId':[],
              #'constructorId':[],
              'number':[]
              #'grid':[],
              #'position':[],
              #'positionText':[],
              #'points':[],
              #'laps':[],
              #'time':[],
              #'millis':[],
              #'status':[]
              #'lap':[]
          }

for year in list(range(2021,2023)):
    url = 'http://ergast.com/api/f1/{}/sprint.json'
    response = requests.get(url.format(year))
    content = json.loads(response.content)
    
    for item in content['MRData']['RaceTable']['Races'][1]['SprintResults']:   
        SprintResults['raceName'].append(content['MRData']['RaceTable']['Races'][1]['raceName'])
        SprintResults['number'].append(int(item['number']))


pd.DataFrame(SprintResults)
# Out:
#                raceName  number
# 0    Italian Grand Prix      77
# 1    Italian Grand Prix      33
# 2    Italian Grand Prix       3
# 3    Italian Grand Prix       4
# 4    Italian Grand Prix      44
# 5    Italian Grand Prix      16
# 6    Italian Grand Prix      55
# 7    Italian Grand Prix      99
# 8    Italian Grand Prix      11
# 9    Italian Grand Prix      18
# 10  Austrian Grand Prix       1
# 11  Austrian Grand Prix      16
# 12  Austrian Grand Prix      55
# 13  Austrian Grand Prix      63
# 14  Austrian Grand Prix      11
# 15  Austrian Grand Prix      31
# 16  Austrian Grand Prix      20
# 17  Austrian Grand Prix      44
# 18  Austrian Grand Prix      47
# 19  Austrian Grand Prix      77

# %%
url='http://ergast.com/api/f1/2011/status.json'
response = requests.get(url)
content = json.loads(response.content);content

(content['MRData']['StatusTable'])
# Out:
# {'season': '2011',
#  'Status': [{'statusId': '1', 'count': '173', 'status': 'Finished'},
#   {'statusId': '2', 'count': '2', 'status': 'Disqualified'},
#   {'statusId': '3', 'count': '14', 'status': 'Accident'},
#   {'statusId': '4', 'count': '16', 'status': 'Collision'},
#   {'statusId': '5', 'count': '4', 'status': 'Engine'},
#   {'statusId': '6', 'count': '12', 'status': 'Gearbox'},
#   {'statusId': '7', 'count': '3', 'status': 'Transmission'},
#   {'statusId': '8', 'count': '2', 'status': 'Clutch'},
#   {'statusId': '9', 'count': '3', 'status': 'Hydraulics'},
#   {'statusId': '10', 'count': '1', 'status': 'Electrical'},
#   {'statusId': '11', 'count': '121', 'status': '+1 Lap'},
#   {'statusId': '12', 'count': '46', 'status': '+2 Laps'},
#   {'statusId': '13', 'count': '17', 'status': '+3 Laps'},
#   {'statusId': '14', 'count': '8', 'status': '+4 Laps'},
#   {'statusId': '15', 'count': '5', 'status': '+5 Laps'},
#   {'statusId': '19', 'count': '1', 'status': '+9 Laps'},
#   {'statusId': '22', 'count': '3', 'status': 'Suspension'},
#   {'statusId': '23', 'count': '1', 'status': 'Brakes'},
#   {'statusId': '26', 'count': '1', 'status': 'Mechanical'},
#   {'statusId': '29', 'count': '1', 'status': 'Puncture'},
#   {'statusId': '31', 'count': '5', 'status': 'Retired'},
#   {'statusId': '36', 'count': '2', 'status': 'Wheel'},
#   {'statusId': '42', 'count': '1', 'status': 'Heat shield fire'},
#   {'statusId': '44', 'count': '3', 'status': 'Oil leak'},
#   {'statusId': '47', 'count': '2', 'status': 'Water leak'},
#   {'statusId': '61', 'count': '1', 'status': 'Wheel nut'},
#   {'statusId': '65', 'count': '1', 'status': 'Rear wing'},
#   {'statusId': '81', 'count': '2', 'status': 'Did not qualify'},
#   {'statusId': '82', 'count': '1', 'status': 'Injury'},
#   {'statusId': '88', 'count': '1', 'status': '+10 Laps'}]}

# %%
status = { 'season':[],
          'statusId':[],
          'status':[]
         }

for year in list(range(2010,2023)):
    url='http://ergast.com/api/f1/{}/status.json'
    response = requests.get(url.format(year))
    content = json.loads(response.content)
    for i in range(0, len(content['MRData']['StatusTable']['Status'])):
            status['season'].append(int(year))
            status['statusId'].append(content['MRData']['StatusTable']['Status'][i]['statusId'])
            status['status'].append(content['MRData']['StatusTable']['Status'][i]['status'])

pd.DataFrame(status)
# Out:
#      season statusId            status
# 0      2010        1          Finished
# 1      2010        3          Accident
# 2      2010        4         Collision
# 3      2010        5            Engine
# 4      2010        6           Gearbox
# ..      ...      ...               ...
# 356    2022      103        Water pump
# 357    2022      130  Collision damage
# 358    2022      131        Power Unit
# 359    2022      140         Undertray
# 360    2022      141    Cooling system
#
# [361 rows x 3 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9480\1754387856.py in <module>
#      11         for item in content['MRData']['StatusTable']['Status']:
#      12             status['season'].append(int(year))
# ---> 13             status['statusId'].append(item[i]['statusId'])
#      14             status['status'].append(item[i]['status'])
#      15
#
# KeyError: 0

# %%
content['MRData']['StatusTable']['Status']
# Out:
# [{'statusId': '1', 'count': '217', 'status': 'Finished'},
#  {'statusId': '2', 'count': '1', 'status': 'Disqualified'},
#  {'statusId': '3', 'count': '6', 'status': 'Accident'},
#  {'statusId': '4', 'count': '20', 'status': 'Collision'},
#  {'statusId': '5', 'count': '2', 'status': 'Engine'},
#  {'statusId': '6', 'count': '5', 'status': 'Gearbox'},
#  {'statusId': '9', 'count': '1', 'status': 'Hydraulics'},
#  {'statusId': '10', 'count': '1', 'status': 'Electrical'},
#  {'statusId': '11', 'count': '130', 'status': '+1 Lap'},
#  {'statusId': '12', 'count': '28', 'status': '+2 Laps'},
#  {'statusId': '13', 'count': '6', 'status': '+3 Laps'},
#  {'statusId': '22', 'count': '2', 'status': 'Suspension'},
#  {'statusId': '23', 'count': '3', 'status': 'Brakes'},
#  {'statusId': '26', 'count': '1', 'status': 'Mechanical'},
#  {'statusId': '29', 'count': '1', 'status': 'Puncture'},
#  {'statusId': '30', 'count': '1', 'status': 'Driveshaft'},
#  {'statusId': '31', 'count': '3', 'status': 'Retired'},
#  {'statusId': '44', 'count': '1', 'status': 'Oil leak'},
#  {'statusId': '61', 'count': '1', 'status': 'Wheel nut'},
#  {'statusId': '65', 'count': '1', 'status': 'Rear wing'},
#  {'statusId': '75', 'count': '1', 'status': 'Power loss'},
#  {'statusId': '101', 'count': '1', 'status': 'Turbo'},
#  {'statusId': '130', 'count': '3', 'status': 'Collision damage'},
#  {'statusId': '131', 'count': '2', 'status': 'Power Unit'},
#  {'statusId': '137', 'count': '1', 'status': 'Damage'},
#  {'statusId': '139', 'count': '1', 'status': 'Illness'}]

# %%
url = 'http://ergast.com/api/f1/2010/results.json'
response = requests.get(url)
content = json.loads(response.content)
content['MRData']['RaceTable']['Races'][0]
# Out:
# {'season': '2010',
#  'round': '1',
#  'url': 'http://en.wikipedia.org/wiki/2010_Bahrain_Grand_Prix',
#  'raceName': 'Bahrain Grand Prix',
#  'Circuit': {'circuitId': 'bahrain',
#   'url': 'http://en.wikipedia.org/wiki/Bahrain_International_Circuit',
#   'circuitName': 'Bahrain International Circuit',
#   'Location': {'lat': '26.0325',
#    'long': '50.5106',
#    'locality': 'Sakhir',
#    'country': 'Bahrain'}},
#  'date': '2010-03-14',
#  'time': '12:00:00Z',
#  'Results': [{'number': '8',
#    'position': '1',
#    'positionText': '1',
#    'points': '25',
#    'Driver': {'driverId': 'alonso',
#     'permanentNumber': '14',
#     'code': 'ALO',
#     'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#     'givenName': 'Fernando',
#     'familyName': 'Alonso',
#     'dateOfBirth': '1981-07-29',
#     'nationality': 'Spanish'},
#    'Constructor': {'constructorId': 'ferrari',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#     'name': 'Ferrari',
#     'nationality': 'Italian'},
#    'grid': '3',
#    'laps': '49',
#    'status': 'Finished',
#    'Time': {'millis': '5960396', 'time': '1:39:20.396'},
#    'FastestLap': {'rank': '1',
#     'lap': '45',
#     'Time': {'time': '1:58.287'},
#     'AverageSpeed': {'units': 'kph', 'speed': '191.706'}}},
#   {'number': '7',
#    'position': '2',
#    'positionText': '2',
#    'points': '18',
#    'Driver': {'driverId': 'massa',
#     'permanentNumber': '19',
#     'code': 'MAS',
#     'url': 'http://en.wikipedia.org/wiki/Felipe_Massa',
#     'givenName': 'Felipe',
#     'familyName': 'Massa',
#     'dateOfBirth': '1981-04-25',
#     'nationality': 'Brazilian'},
#    'Constructor': {'constructorId': 'ferrari',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#     'name': 'Ferrari',
#     'nationality': 'Italian'},
#    'grid': '2',
#    'laps': '49',
#    'status': 'Finished',
#    'Time': {'millis': '5976495', 'time': '+16.099'},
#    'FastestLap': {'rank': '5',
#     'lap': '38',
#     'Time': {'time': '1:59.732'},
#     'AverageSpeed': {'units': 'kph', 'speed': '189.392'}}},
#   {'number': '2',
#    'position': '3',
#    'positionText': '3',
#    'points': '15',
#    'Driver': {'driverId': 'hamilton',
#     'permanentNumber': '44',
#     'code': 'HAM',
#     'url': 'http://en.wikipedia.org/wiki/Lewis_Hamilton',
#     'givenName': 'Lewis',
#     'familyName': 'Hamilton',
#     'dateOfBirth': '1985-01-07',
#     'nationality': 'British'},
#    'Constructor': {'constructorId': 'mclaren',
#     'url': 'http://en.wikipedia.org/wiki/McLaren',
#     'name': 'McLaren',
#     'nationality': 'British'},
#    'grid': '4',
#    'laps': '49',
#    'status': 'Finished',
#    'Time': {'millis': '5983578', 'time': '+23.182'},
#    'FastestLap': {'rank': '4',
#     'lap': '42',
#     'Time': {'time': '1:59.560'},
#     'AverageSpeed': {'units': 'kph', 'speed': '189.665'}}},
#   {'number': '5',
#    'position': '4',
#    'positionText': '4',
#    'points': '12',
#    'Driver': {'driverId': 'vettel',
#     'permanentNumber': '5',
#     'code': 'VET',
#     'url': 'http://en.wikipedia.org/wiki/Sebastian_Vettel',
#     'givenName': 'Sebastian',
#     'familyName': 'Vettel',
#     'dateOfBirth': '1987-07-03',
#     'nationality': 'German'},
#    'Constructor': {'constructorId': 'red_bull',
#     'url': 'http://en.wikipedia.org/wiki/Red_Bull_Racing',
#     'name': 'Red Bull',
#     'nationality': 'Austrian'},
#    'grid': '1',
#    'laps': '49',
#    'status': 'Finished',
#    'Time': {'millis': '5999195', 'time': '+38.799'},
#    'FastestLap': {'rank': '12',
#     'lap': '32',
#     'Time': {'time': '2:00.218'},
#     'AverageSpeed': {'units': 'kph', 'speed': '188.627'}}},
#   {'number': '4',
#    'position': '5',
#    'positionText': '5',
#    'points': '10',
#    'Driver': {'driverId': 'rosberg',
#     'permanentNumber': '6',
#     'code': 'ROS',
#     'url': 'http://en.wikipedia.org/wiki/Nico_Rosberg',
#     'givenName': 'Nico',
#     'familyName': 'Rosberg',
#     'dateOfBirth': '1985-06-27',
#     'nationality': 'German'},
#    'Constructor': {'constructorId': 'mercedes',
#     'url': 'http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One',
#     'name': 'Mercedes',
#     'nationality': 'German'},
#    'grid': '5',
#    'laps': '49',
#    'status': 'Finished',
#    'Time': {'millis': '6000609', 'time': '+40.213'},
#    'FastestLap': {'rank': '13',
#     'lap': '45',
#     'Time': {'time': '2:00.236'},
#     'AverageSpeed': {'units': 'kph', 'speed': '188.599'}}},
#   {'number': '3',
#    'position': '6',
#    'positionText': '6',
#    'points': '8',
#    'Driver': {'driverId': 'michael_schumacher',
#     'code': 'MSC',
#     'url': 'http://en.wikipedia.org/wiki/Michael_Schumacher',
#     'givenName': 'Michael',
#     'familyName': 'Schumacher',
#     'dateOfBirth': '1969-01-03',
#     'nationality': 'German'},
#    'Constructor': {'constructorId': 'mercedes',
#     'url': 'http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One',
#     'name': 'Mercedes',
#     'nationality': 'German'},
#    'grid': '7',
#    'laps': '49',
#    'status': 'Finished',
#    'Time': {'millis': '6004559', 'time': '+44.163'},
#    'FastestLap': {'rank': '11',
#     'lap': '45',
#     'Time': {'time': '2:00.204'},
#     'AverageSpeed': {'units': 'kph', 'speed': '188.649'}}},
#   {'number': '1',
#    'position': '7',
#    'positionText': '7',
#    'points': '6',
#    'Driver': {'driverId': 'button',
#     'permanentNumber': '22',
#     'code': 'BUT',
#     'url': 'http://en.wikipedia.org/wiki/Jenson_Button',
#     'givenName': 'Jenson',
#     'familyName': 'Button',
#     'dateOfBirth': '1980-01-19',
#     'nationality': 'British'},
#    'Constructor': {'constructorId': 'mclaren',
#     'url': 'http://en.wikipedia.org/wiki/McLaren',
#     'name': 'McLaren',
#     'nationality': 'British'},
#    'grid': '8',
#    'laps': '49',
#    'status': 'Finished',
#    'Time': {'millis': '6005676', 'time': '+45.280'},
#    'FastestLap': {'rank': '9',
#     'lap': '45',
#     'Time': {'time': '1:59.970'},
#     'AverageSpeed': {'units': 'kph', 'speed': '189.017'}}},
#   {'number': '6',
#    'position': '8',
#    'positionText': '8',
#    'points': '4',
#    'Driver': {'driverId': 'webber',
#     'code': 'WEB',
#     'url': 'http://en.wikipedia.org/wiki/Mark_Webber_(racing_driver)',
#     'givenName': 'Mark',
#     'familyName': 'Webber',
#     'dateOfBirth': '1976-08-27',
#     'nationality': 'Australian'},
#    'Constructor': {'constructorId': 'red_bull',
#     'url': 'http://en.wikipedia.org/wiki/Red_Bull_Racing',
#     'name': 'Red Bull',
#     'nationality': 'Austrian'},
#    'grid': '6',
#    'laps': '49',
#    'status': 'Finished',
#    'Time': {'millis': '6006756', 'time': '+46.360'},
#    'FastestLap': {'rank': '3',
#     'lap': '45',
#     'Time': {'time': '1:59.487'},
#     'AverageSpeed': {'units': 'kph', 'speed': '189.781'}}},
#   {'number': '15',
#    'position': '9',
#    'positionText': '9',
#    'points': '2',
#    'Driver': {'driverId': 'liuzzi',
#     'code': 'LIU',
#     'url': 'http://en.wikipedia.org/wiki/Vitantonio_Liuzzi',
#     'givenName': 'Vitantonio',
#     'familyName': 'Liuzzi',
#     'dateOfBirth': '1980-08-06',
#     'nationality': 'Italian'},
#    'Constructor': {'constructorId': 'force_india',
#     'url': 'http://en.wikipedia.org/wiki/Racing_Point_Force_India',
#     'name': 'Force India',
#     'nationality': 'Indian'},
#    'grid': '12',
#    'laps': '49',
#    'status': 'Finished',
#    'Time': {'millis': '6013404', 'time': '+53.008'},
#    'FastestLap': {'rank': '7',
#     'lap': '39',
#     'Time': {'time': '1:59.906'},
#     'AverageSpeed': {'units': 'kph', 'speed': '189.118'}}},
#   {'number': '9',
#    'position': '10',
#    'positionText': '10',
#    'points': '1',
#    'Driver': {'driverId': 'barrichello',
#     'code': 'BAR',
#     'url': 'http://en.wikipedia.org/wiki/Rubens_Barrichello',
#     'givenName': 'Rubens',
#     'familyName': 'Barrichello',
#     'dateOfBirth': '1972-05-23',
#     'nationality': 'Brazilian'},
#    'Constructor': {'constructorId': 'williams',
#     'url': 'http://en.wikipedia.org/wiki/Williams_Grand_Prix_Engineering',
#     'name': 'Williams',
#     'nationality': 'British'},
#    'grid': '11',
#    'laps': '49',
#    'status': 'Finished',
#    'Time': {'millis': '6022885', 'time': '+1:02.489'},
#    'FastestLap': {'rank': '6',
#     'lap': '47',
#     'Time': {'time': '1:59.833'},
#     'AverageSpeed': {'units': 'kph', 'speed': '189.233'}}},
#   {'number': '11',
#    'position': '11',
#    'positionText': '11',
#    'points': '0',
#    'Driver': {'driverId': 'kubica',
#     'permanentNumber': '88',
#     'code': 'KUB',
#     'url': 'http://en.wikipedia.org/wiki/Robert_Kubica',
#     'givenName': 'Robert',
#     'familyName': 'Kubica',
#     'dateOfBirth': '1984-12-07',
#     'nationality': 'Polish'},
#    'Constructor': {'constructorId': 'renault',
#     'url': 'http://en.wikipedia.org/wiki/Renault_in_Formula_One',
#     'name': 'Renault',
#     'nationality': 'French'},
#    'grid': '9',
#    'laps': '49',
#    'status': 'Finished',
#    'Time': {'millis': '6029489', 'time': '+1:09.093'},
#    'FastestLap': {'rank': '14',
#     'lap': '33',
#     'Time': {'time': '2:00.474'},
#     'AverageSpeed': {'units': 'kph', 'speed': '188.226'}}},
#   {'number': '14',
#    'position': '12',
#    'positionText': '12',
#    'points': '0',
#    'Driver': {'driverId': 'sutil',
#     'permanentNumber': '99',
#     'code': 'SUT',
#     'url': 'http://en.wikipedia.org/wiki/Adrian_Sutil',
#     'givenName': 'Adrian',
#     'familyName': 'Sutil',
#     'dateOfBirth': '1983-01-11',
#     'nationality': 'German'},
#    'Constructor': {'constructorId': 'force_india',
#     'url': 'http://en.wikipedia.org/wiki/Racing_Point_Force_India',
#     'name': 'Force India',
#     'nationality': 'Indian'},
#    'grid': '10',
#    'laps': '49',
#    'status': 'Finished',
#    'Time': {'millis': '6043354', 'time': '+1:22.958'},
#    'FastestLap': {'rank': '2',
#     'lap': '49',
#     'Time': {'time': '1:59.393'},
#     'AverageSpeed': {'units': 'kph', 'speed': '189.930'}}},
#   {'number': '17',
#    'position': '13',
#    'positionText': '13',
#    'points': '0',
#    'Driver': {'driverId': 'alguersuari',
#     'code': 'ALG',
#     'url': 'http://en.wikipedia.org/wiki/Jaime_Alguersuari',
#     'givenName': 'Jaime',
#     'familyName': 'Alguersuari',
#     'dateOfBirth': '1990-03-23',
#     'nationality': 'Spanish'},
#    'Constructor': {'constructorId': 'toro_rosso',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso',
#     'name': 'Toro Rosso',
#     'nationality': 'Italian'},
#    'grid': '18',
#    'laps': '49',
#    'status': 'Finished',
#    'Time': {'millis': '6053052', 'time': '+1:32.656'},
#    'FastestLap': {'rank': '8',
#     'lap': '28',
#     'Time': {'time': '1:59.964'},
#     'AverageSpeed': {'units': 'kph', 'speed': '189.026'}}},
#   {'number': '10',
#    'position': '14',
#    'positionText': '14',
#    'points': '0',
#    'Driver': {'driverId': 'hulkenberg',
#     'permanentNumber': '27',
#     'code': 'HUL',
#     'url': 'http://en.wikipedia.org/wiki/Nico_H%C3%BClkenberg',
#     'givenName': 'Nico',
#     'familyName': 'Hülkenberg',
#     'dateOfBirth': '1987-08-19',
#     'nationality': 'German'},
#    'Constructor': {'constructorId': 'williams',
#     'url': 'http://en.wikipedia.org/wiki/Williams_Grand_Prix_Engineering',
#     'name': 'Williams',
#     'nationality': 'British'},
#    'grid': '13',
#    'laps': '48',
#    'status': '+1 Lap',
#    'FastestLap': {'rank': '15',
#     'lap': '34',
#     'Time': {'time': '2:01.401'},
#     'AverageSpeed': {'units': 'kph', 'speed': '186.789'}}},
#   {'number': '19',
#    'position': '15',
#    'positionText': '15',
#    'points': '0',
#    'Driver': {'driverId': 'kovalainen',
#     'code': 'KOV',
#     'url': 'http://en.wikipedia.org/wiki/Heikki_Kovalainen',
#     'givenName': 'Heikki',
#     'familyName': 'Kovalainen',
#     'dateOfBirth': '1981-10-19',
#     'nationality': 'Finnish'},
#    'Constructor': {'constructorId': 'lotus_racing',
#     'url': 'http://en.wikipedia.org/wiki/Lotus_Racing',
#     'name': 'Lotus',
#     'nationality': 'Malaysian'},
#    'grid': '21',
#    'laps': '47',
#    'status': '+2 Laps',
#    'FastestLap': {'rank': '17',
#     'lap': '47',
#     'Time': {'time': '2:02.701'},
#     'AverageSpeed': {'units': 'kph', 'speed': '184.810'}}},
#   {'number': '16',
#    'position': '16',
#    'positionText': '16',
#    'points': '0',
#    'Driver': {'driverId': 'buemi',
#     'code': 'BUE',
#     'url': 'http://en.wikipedia.org/wiki/S%C3%A9bastien_Buemi',
#     'givenName': 'Sébastien',
#     'familyName': 'Buemi',
#     'dateOfBirth': '1988-10-31',
#     'nationality': 'Swiss'},
#    'Constructor': {'constructorId': 'toro_rosso',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso',
#     'name': 'Toro Rosso',
#     'nationality': 'Italian'},
#    'grid': '15',
#    'laps': '46',
#    'status': 'Electrical',
#    'FastestLap': {'rank': '10',
#     'lap': '41',
#     'Time': {'time': '2:00.080'},
#     'AverageSpeed': {'units': 'kph', 'speed': '188.844'}}},
#   {'number': '18',
#    'position': '17',
#    'positionText': '17',
#    'points': '0',
#    'Driver': {'driverId': 'trulli',
#     'code': 'TRU',
#     'url': 'http://en.wikipedia.org/wiki/Jarno_Trulli',
#     'givenName': 'Jarno',
#     'familyName': 'Trulli',
#     'dateOfBirth': '1974-07-13',
#     'nationality': 'Italian'},
#    'Constructor': {'constructorId': 'lotus_racing',
#     'url': 'http://en.wikipedia.org/wiki/Lotus_Racing',
#     'name': 'Lotus',
#     'nationality': 'Malaysian'},
#    'grid': '20',
#    'laps': '46',
#    'status': 'Hydraulics',
#    'FastestLap': {'rank': '18',
#     'lap': '34',
#     'Time': {'time': '2:02.930'},
#     'AverageSpeed': {'units': 'kph', 'speed': '184.465'}}},
#   {'number': '22',
#    'position': '18',
#    'positionText': 'R',
#    'points': '0',
#    'Driver': {'driverId': 'rosa',
#     'code': 'DLR',
#     'url': 'http://en.wikipedia.org/wiki/Pedro_de_la_Rosa',
#     'givenName': 'Pedro',
#     'familyName': 'de la Rosa',
#     'dateOfBirth': '1971-02-24',
#     'nationality': 'Spanish'},
#    'Constructor': {'constructorId': 'sauber',
#     'url': 'http://en.wikipedia.org/wiki/Sauber',
#     'name': 'Sauber',
#     'nationality': 'Swiss'},
#    'grid': '14',
#    'laps': '28',
#    'status': 'Hydraulics',
#    'FastestLap': {'rank': '16',
#     'lap': '27',
#     'Time': {'time': '2:01.650'},
#     'AverageSpeed': {'units': 'kph', 'speed': '186.406'}}},
#   {'number': '21',
#    'position': '19',
#    'positionText': 'R',
#    'points': '0',
#    'Driver': {'driverId': 'bruno_senna',
#     'code': 'SEN',
#     'url': 'http://en.wikipedia.org/wiki/Bruno_Senna',
#     'givenName': 'Bruno',
#     'familyName': 'Senna',
#     'dateOfBirth': '1983-10-15',
#     'nationality': 'Brazilian'},
#    'Constructor': {'constructorId': 'hrt',
#     'url': 'http://en.wikipedia.org/wiki/Hispania_Racing',
#     'name': 'HRT',
#     'nationality': 'Spanish'},
#    'grid': '23',
#    'laps': '17',
#    'status': 'Overheating',
#    'FastestLap': {'rank': '22',
#     'lap': '14',
#     'Time': {'time': '2:09.127'},
#     'AverageSpeed': {'units': 'kph', 'speed': '175.613'}}},
#   {'number': '24',
#    'position': '20',
#    'positionText': 'R',
#    'points': '0',
#    'Driver': {'driverId': 'glock',
#     'code': 'GLO',
#     'url': 'http://en.wikipedia.org/wiki/Timo_Glock',
#     'givenName': 'Timo',
#     'familyName': 'Glock',
#     'dateOfBirth': '1982-03-18',
#     'nationality': 'German'},
#    'Constructor': {'constructorId': 'virgin',
#     'url': 'http://en.wikipedia.org/wiki/Virgin_Racing',
#     'name': 'Virgin',
#     'nationality': 'British'},
#    'grid': '19',
#    'laps': '16',
#    'status': 'Gearbox',
#    'FastestLap': {'rank': '21',
#     'lap': '11',
#     'Time': {'time': '2:07.062'},
#     'AverageSpeed': {'units': 'kph', 'speed': '178.467'}}},
#   {'number': '12',
#    'position': '21',
#    'positionText': 'R',
#    'points': '0',
#    'Driver': {'driverId': 'petrov',
#     'code': 'PET',
#     'url': 'http://en.wikipedia.org/wiki/Vitaly_Petrov',
#     'givenName': 'Vitaly',
#     'familyName': 'Petrov',
#     'dateOfBirth': '1984-09-08',
#     'nationality': 'Russian'},
#    'Constructor': {'constructorId': 'renault',
#     'url': 'http://en.wikipedia.org/wiki/Renault_in_Formula_One',
#     'name': 'Renault',
#     'nationality': 'French'},
#    'grid': '17',
#    'laps': '13',
#    'status': 'Suspension',
#    'FastestLap': {'rank': '19',
#     'lap': '7',
#     'Time': {'time': '2:04.307'},
#     'AverageSpeed': {'units': 'kph', 'speed': '182.422'}}},
#   {'number': '23',
#    'position': '22',
#    'positionText': 'R',
#    'points': '0',
#    'Driver': {'driverId': 'kobayashi',
#     'permanentNumber': '10',
#     'code': 'KOB',
#     'url': 'http://en.wikipedia.org/wiki/Kamui_Kobayashi',
#     'givenName': 'Kamui',
#     'familyName': 'Kobayashi',
#     'dateOfBirth': '1986-09-13',
#     'nationality': 'Japanese'},
#    'Constructor': {'constructorId': 'sauber',
#     'url': 'http://en.wikipedia.org/wiki/Sauber',
#     'name': 'Sauber',
#     'nationality': 'Swiss'},
#    'grid': '16',
#    'laps': '11',
#    'status': 'Hydraulics',
#    'FastestLap': {'rank': '20',
#     'lap': '4',
#     'Time': {'time': '2:05.044'},
#     'AverageSpeed': {'units': 'kph', 'speed': '181.347'}}},
#   {'number': '25',
#    'position': '23',
#    'positionText': 'R',
#    'points': '0',
#    'Driver': {'driverId': 'grassi',
#     'code': 'DIG',
#     'url': 'http://en.wikipedia.org/wiki/Lucas_di_Grassi',
#     'givenName': 'Lucas',
#     'familyName': 'di Grassi',
#     'dateOfBirth': '1984-08-11',
#     'nationality': 'Brazilian'},
#    'Constructor': {'constructorId': 'virgin',
#     'url': 'http://en.wikipedia.org/wiki/Virgin_Racing',
#     'name': 'Virgin',
#     'nationality': 'British'},
#    'grid': '22',
#    'laps': '2',
#    'status': 'Hydraulics',
#    'FastestLap': {'rank': '23',
#     'lap': '2',
#     'Time': {'time': '2:09.361'},
#     'AverageSpeed': {'units': 'kph', 'speed': '175.295'}}},
#   {'number': '20',
#    'position': '24',
#    'positionText': 'R',
#    'points': '0',
#    'Driver': {'driverId': 'chandhok',
#     'code': 'CHA',
#     'url': 'http://en.wikipedia.org/wiki/Karun_Chandhok',
#     'givenName': 'Karun',
#     'familyName': 'Chandhok',
#     'dateOfBirth': '1984-01-19',
#     'nationality': 'Indian'},
#    'Constructor': {'constructorId': 'hrt',
#     'url': 'http://en.wikipedia.org/wiki/Hispania_Racing',
#     'name': 'HRT',
#     'nationality': 'Spanish'},
#    'grid': '24',
#    'laps': '1',
#    'status': 'Accident'}]}

# %%
Results = {'raceName':[],
              'driverId':[],
              'constructorId':[],
              'number':[],
              'grid':[],
              'position':[],
              'positionText':[],
              'points':[],
              'laps':[],
              'time':[],
              'millis':[],
              'fastestlap':[],
              'rank':[],
              'fastestlaptime':[],
              'fastestlapspeed':[],
              'status':[],
          }

for year in list(range(2010,2023)):
    url = 'http://ergast.com/api/f1/{}/results.json'
    response = requests.get(url.format(year))
    content = json.loads(response.content)

    for i in range(0, len(content['MRData']['RaceTable']['Races'])):
        for item in content['MRData']['RaceTable']['Races'][i]['Results']:
            Results['raceName'].append(content['MRData']['RaceTable']['Races'][i]['raceName'])
            Results['driverId'].append(item['Driver']['driverId'])
            Results['constructorId'].append(item['Constructor']['constructorId'])
            Results['number'].append(int(item['number']))
            Results['grid'].append(int(item['grid']))
            Results['position'].append(int(item['position']))
            Results['positionText'].append(item['positionText'])
            Results['points'].append(int(item['points']))
            Results['laps'].append(int(item['laps']))
            Results['status'].append(item['status'])
            try:
                Results['time'].append(item['Time']['time'])
            except:
                Results['time'].append(None)
            try:
                Results['millis'].append(int(item['Time']['millis']))
            except:
                Results['millis'].append(None)
            try:
                Results['fastestlap'].append(item['FastestLap']['lap'])
            except:
                Results['fastestlap'].append(None)
            try:
                Results['rank'].append(int(item['FastestLap']['rank']))
            except:
                Results['rank'].append(None)
            try:
                Results['fastestlaptime'].append(item['FastestLap']['Time']['time'])
            except:
                Results['fastestlaptime'].append(None)
            try:
                Results['fastestlapspeed'].append(float(item['FastestLap']['AverageSpeed']['speed']))
            except:
                Results['fastestlapspeed'].append(None)


pd.DataFrame(Results)
# Out:
#                      raceName         driverId constructorId  number  grid  \
# 0          Bahrain Grand Prix           alonso       ferrari       8     3
# 1          Bahrain Grand Prix            massa       ferrari       7     2
# 2          Bahrain Grand Prix         hamilton       mclaren       2     4
# 3          Bahrain Grand Prix           vettel      red_bull       5     1
# 4          Bahrain Grand Prix          rosberg      mercedes       4     5
# ..                        ...              ...           ...     ...   ...
# 385  Saudi Arabian Grand Prix             ocon        alpine      31     5
# 386  Saudi Arabian Grand Prix           norris       mclaren       4    11
# 387  Saudi Arabian Grand Prix            gasly    alphatauri      10     9
# 388  Saudi Arabian Grand Prix  kevin_magnussen          haas      20    10
# 389  Saudi Arabian Grand Prix         hamilton      mercedes      44    15
#
#      position positionText  points  laps         time     millis fastestlap  \
# 0           1            1      25    49  1:39:20.396  5960396.0         45
# 1           2            2      18    49      +16.099  5976495.0         38
# 2           3            3      15    49      +23.182  5983578.0         42
# 3           4            4      12    49      +38.799  5999195.0         32
# 4           5            5      10    49      +40.213  6000609.0         45
# ..        ...          ...     ...   ...          ...        ...        ...
# 385         6            6       8    50      +56.017  5115310.0         46
# 386         7            7       6    50      +56.124  5115417.0         46
# 387         8            8       4    50    +1:02.946  5122239.0         42
# 388         9            9       2    50    +1:04.308  5123601.0         48
# 389        10           10       1    50    +1:13.948  5133241.0         47
#
#      rank fastestlaptime  fastestlapspeed    status
# 0     1.0       1:58.287          191.706  Finished
# 1     5.0       1:59.732          189.392  Finished
# 2     4.0       1:59.560          189.665  Finished
# 3    12.0       2:00.218          188.627  Finished
# 4    13.0       2:00.236          188.599  Finished
# ..    ...            ...              ...       ...
# 385   9.0       1:33.103          238.729  Finished
# 386   5.0       1:32.753          239.629  Finished
# 387  10.0       1:33.468          237.796  Finished
# 388   6.0       1:32.779          239.562  Finished
# 389   8.0       1:32.997          239.001  Finished
#
# [390 rows x 16 columns]

# %%
pd.DataFrame(SprintResults).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   raceName         60 non-null     object
#  1   driverId         60 non-null     object
#  2   constructorId    60 non-null     object
#  3   number           60 non-null     int64
#  4   grid             60 non-null     int64
#  5   position         60 non-null     int64
#  6   positionText     60 non-null     object
#  7   points           60 non-null     int64
#  8   laps             60 non-null     int64
#  9   time             48 non-null     object
#  10  millis           48 non-null     float64
#  11  fastestlap       59 non-null     object
#  12  rank             59 non-null     float64
#  13  fastestlaptime   59 non-null     object
#  14  fastestlapspeed  59 non-null     float64
#  15  status           60 non-null     object
# dtypes: float64(3), int64(5), object(8)
# memory usage: 7.6+ KB

# %%
url = 'http://ergast.com/api/f1/2011/5/pitstops.json'
response = requests.get(url)
content = json.loads(response.content)
content['MRData']['RaceTable']['Races']
# Out:
# [{'season': '2011',
#   'round': '5',
#   'url': 'http://en.wikipedia.org/wiki/2011_Spanish_Grand_Prix',
#   'raceName': 'Spanish Grand Prix',
#   'Circuit': {'circuitId': 'catalunya',
#    'url': 'http://en.wikipedia.org/wiki/Circuit_de_Barcelona-Catalunya',
#    'circuitName': 'Circuit de Barcelona-Catalunya',
#    'Location': {'lat': '41.57',
#     'long': '2.26111',
#     'locality': 'Montmeló',
#     'country': 'Spain'}},
#   'date': '2011-05-22',
#   'time': '12:00:00Z',
#   'PitStops': [{'driverId': 'kobayashi',
#     'lap': '1',
#     'stop': '1',
#     'time': '14:05:11',
#     'duration': '24.871'},
#    {'driverId': 'perez',
#     'lap': '7',
#     'stop': '1',
#     'time': '14:14:14',
#     'duration': '23.592'},
#    {'driverId': 'maldonado',
#     'lap': '8',
#     'stop': '1',
#     'time': '14:15:48',
#     'duration': '22.689'},
#    {'driverId': 'vettel',
#     'lap': '9',
#     'stop': '1',
#     'time': '14:16:54',
#     'duration': '20.253'},
#    {'driverId': 'buemi',
#     'lap': '9',
#     'stop': '1',
#     'time': '14:17:17',
#     'duration': '20.818'},
#    {'driverId': 'alonso',
#     'lap': '10',
#     'stop': '1',
#     'time': '14:18:23',
#     'duration': '20.567'},
#    {'driverId': 'webber',
#     'lap': '10',
#     'stop': '1',
#     'time': '14:18:27',
#     'duration': '20.881'},
#    {'driverId': 'michael_schumacher',
#     'lap': '10',
#     'stop': '1',
#     'time': '14:18:43',
#     'duration': '20.084'},
#    {'driverId': 'hamilton',
#     'lap': '11',
#     'stop': '1',
#     'time': '14:19:57',
#     'duration': '19.761'},
#    {'driverId': 'petrov',
#     'lap': '11',
#     'stop': '1',
#     'time': '14:20:14',
#     'duration': '21.856'},
#    {'driverId': 'rosberg',
#     'lap': '11',
#     'stop': '1',
#     'time': '14:20:17',
#     'duration': '20.647'},
#    {'driverId': 'massa',
#     'lap': '11',
#     'stop': '1',
#     'time': '14:20:19',
#     'duration': '20.800'},
#    {'driverId': 'alguersuari',
#     'lap': '11',
#     'stop': '1',
#     'time': '14:20:28',
#     'duration': '20.741'},
#    {'driverId': 'barrichello',
#     'lap': '11',
#     'stop': '1',
#     'time': '14:20:48',
#     'duration': '29.936'},
#    {'driverId': 'sutil',
#     'lap': '13',
#     'stop': '1',
#     'time': '14:23:57',
#     'duration': '20.773'},
#    {'driverId': 'button',
#     'lap': '14',
#     'stop': '1',
#     'time': '14:24:51',
#     'duration': '20.015'},
#    {'driverId': 'karthikeyan',
#     'lap': '14',
#     'stop': '1',
#     'time': '14:25:56',
#     'duration': '24.843'},
#    {'driverId': 'resta',
#     'lap': '15',
#     'stop': '1',
#     'time': '14:26:40',
#     'duration': '20.070'},
#    {'driverId': 'trulli',
#     'lap': '15',
#     'stop': '1',
#     'time': '14:26:50',
#     'duration': '22.364'},
#    {'driverId': 'kovalainen',
#     'lap': '16',
#     'stop': '1',
#     'time': '14:28:30',
#     'duration': '21.019'},
#    {'driverId': 'liuzzi',
#     'lap': '16',
#     'stop': '1',
#     'time': '14:28:55',
#     'duration': '23.157'},
#    {'driverId': 'glock',
#     'lap': '16',
#     'stop': '1',
#     'time': '14:29:00',
#     'duration': '22.744'},
#    {'driverId': 'ambrosio',
#     'lap': '17',
#     'stop': '1',
#     'time': '14:30:41',
#     'duration': '23.176'},
#    {'driverId': 'vettel',
#     'lap': '18',
#     'stop': '2',
#     'time': '14:30:44',
#     'duration': '19.887'},
#    {'driverId': 'alonso',
#     'lap': '19',
#     'stop': '2',
#     'time': '14:32:13',
#     'duration': '20.238'},
#    {'driverId': 'webber',
#     'lap': '19',
#     'stop': '2',
#     'time': '14:32:16',
#     'duration': '20.079'},
#    {'driverId': 'maldonado',
#     'lap': '20',
#     'stop': '2',
#     'time': '14:34:36',
#     'duration': '24.821'},
#    {'driverId': 'massa',
#     'lap': '21',
#     'stop': '2',
#     'time': '14:35:51',
#     'duration': '21.635'},
#    {'driverId': 'heidfeld',
#     'lap': '21',
#     'stop': '1',
#     'time': '14:36:21',
#     'duration': '21.322'},
#    {'driverId': 'hamilton',
#     'lap': '23',
#     'stop': '2',
#     'time': '14:38:08',
#     'duration': '20.235'}]}]

# %%
PitStops = {'raceName': [],
           'driverId':[],
           'stop':[],
           'lap':[],
           'time':[],
           'duration':[]
           }

for year in list(range(2011,2023)):
    url= 'http://ergast.com/api/f1/{}/5/pitstops.json'
    response = requests.get(url.format(year))
    content = json.loads(response.content)
            

    for item in content['MRData']['RaceTable']['Races']:
        for i in list(range(0, len(content['MRData']['RaceTable']['Races'][0]['PitStops']))):
            PitStops['raceName'].append(item['raceName'])
            PitStops['driverId'].append(item['PitStops'][i]['driverId'])
            PitStops['lap'].append(int(item['PitStops'][i]['lap']))
            PitStops['stop'].append(int(item['PitStops'][i]['stop']))
            PitStops['time'].append(item['PitStops'][i]['time'])
            PitStops['duration'].append(item['PitStops'][i]['duration'])
        

pd.DataFrame(PitStops)
# Out:
#                raceName         driverId  stop  lap      time duration
# 0    Spanish Grand Prix        kobayashi     1    1  14:05:11   24.871
# 1    Spanish Grand Prix            perez     1    7  14:14:14   23.592
# 2    Spanish Grand Prix        maldonado     1    8  14:15:48   22.689
# 3    Spanish Grand Prix           vettel     1    9  14:16:54   20.253
# 4    Spanish Grand Prix            buemi     1    9  14:17:17   20.818
# ..                  ...              ...   ...  ...       ...      ...
# 330    Miami Grand Prix           vettel     1   41  16:39:42   19.861
# 331    Miami Grand Prix        ricciardo     2   41  16:39:49   19.280
# 332    Miami Grand Prix          tsunoda     2   41  16:40:43   19.618
# 333    Miami Grand Prix  kevin_magnussen     2   42  16:41:34   20.673
# 334    Miami Grand Prix  mick_schumacher     2   54  17:03:43   32.381
#
# [335 rows x 6 columns]

# %%
pd.DataFrame(PitStops).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 335 entries, 0 to 334
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   raceName  335 non-null    object
#  1   driverId  335 non-null    object
#  2   stop      335 non-null    int64
#  3   lap       335 non-null    int64
#  4   time      335 non-null    object
#  5   duration  335 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 15.8+ KB
